# %%
# !pip install clean-fid

# %%
# !python diffusion_vs_flows.py
# Out:
# Running on cuda
# Loading AFHQ dataset...
# ...
#
# --- Training Diffusion Model ---
# Epoch 1/100: 100% 7/7 [00:07<00:00,  1.00s/it, loss=0.484]
# Epoch 2/100: 100% 7/7 [00:06<00:00,  1.10it/s, loss=0.285]
# Epoch 3/100: 100% 7/7 [00:06<00:00,  1.10it/s, loss=0.214]
# Epoch 4/100: 100% 7/7 [00:06<00:00,  1.10it/s, loss=0.182]
# Epoch 5/100: 100% 7/7 [00:06<00:00,  1.11it/s, loss=0.141]
# Epoch 6/100: 100% 7/7 [00:06<00:00,  1.10it/s, loss=0.155]
# Epoch 7/100: 100% 7/7 [00:06<00:00,  1.11it/s, loss=0.136]
# Epoch 8/100: 100% 7/7 [00:06<00:00,  1.08it/s, loss=0.123]
# Epoch 9/100: 100% 7/7 [00:06<00:00,  1.10it/s, loss=0.107]
# Epoch 10/100: 100% 7/7 [00:06<00:00,  1.11it/s, loss=0.101]
# Epoch 11/100: 100% 7/7 [00:06<00:00,  1.10it/s, loss=0.103]
# Epoch 12/100: 100% 7/7 [00:06<00:00,  1.12it/s, loss=0.116]
# Epoch 13/100: 100% 7/7 [00:06<00:00,  1.11it/s, loss=0.138]
# Epoch 14/100: 100% 7/7 [00:06<00:00,  1.11it/s, loss=0.142]
# ...
